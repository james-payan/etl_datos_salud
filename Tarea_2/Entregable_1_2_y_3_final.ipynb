# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline
import os
import pandas as pd
import nltk
nltk.download("punkt")
nltk.download("punkt_tab")
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# prompt: help me to set the HF_TOKEN environment variable and do login to hugging face

from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %% [markdown]
# # Entregable 1: Clasificar las entidades nombradas de las historias clinicas

# %%
model = AutoModelForTokenClassification.from_pretrained(
    "anvorja/breast-cancer-biomedical-ner-sp"
)
tokenizer = AutoTokenizer.from_pretrained("anvorja/breast-cancer-biomedical-ner-sp")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/3.15k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]

# %%
ner_pipeline = pipeline("token-classification", model=model, tokenizer=tokenizer, aggregation_strategy="simple")
# Out:
# Device set to use cuda:0

# %%
import os
import pandas as pd
from nltk.tokenize import sent_tokenize   # or the splitter you already use


def procesar_historias_clinicas(path):
    """
    Re-implemented so that consecutive entities of the same type (except FECHA)
    are fused into a single row in the output DataFrame.
    """
    datos = []
    archivos = [f for f in os.listdir(path) if f.endswith(".txt")]
    total_archivos = len(archivos)
    print(f"\nSe encontraron {total_archivos} archivos de historias clínicas.\n")

    for idx, archivo in enumerate(archivos, 1):
        print(f"Procesando archivo {idx}/{total_archivos}: {archivo}")
        ruta_archivo = os.path.join(path, archivo)

        with open(ruta_archivo, encoding='utf-8') as f:
            texto = f.read()

        for i, oracion in enumerate(sent_tokenize(texto)):
            entidades = ner_pipeline(oracion)

            for ent in entidades:
                datos.append({
                    "patient_id": archivo.replace(".txt", ""),
                    "sentence_id": i,
                    "sentence": oracion,
                    "NER": ent["word"],
                    "label": ent["entity_group"],
                    "start": ent["start"],
                    "end": ent["end"]
                })

    return pd.DataFrame(datos)

# %%
df_ner = procesar_historias_clinicas("/content/drive/MyDrive/Tareas_Analitica_Datos_Salud/Tarea_2/Notas_Cancer_Mama/")
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Se encontraron 106 archivos de historias clínicas.
#
# Procesando archivo 1/106: 120.txt
# Procesando archivo 2/106: 553284.txt
# Procesando archivo 3/106: 5692361.txt
# Procesando archivo 4/106: 158.txt
# Procesando archivo 5/106: 139.txt
# Procesando archivo 6/106: 261062.txt
# Procesando archivo 7/106: 2567.txt
# Procesando archivo 8/106: 236.txt
# Procesando archivo 9/106: 330177_1.txt
# Procesando archivo 10/106: 2071255.txt
# Procesando archivo 11/106: 163.txt
# Procesando archivo 12/106: 153.txt
# Procesando archivo 13/106: 1010408.txt
# Procesando archivo 14/106: 131.txt
# Procesando archivo 15/106: 125.txt
# Procesando archivo 16/106: 2102.txt
# Procesando archivo 17/106: 1710.txt
# Procesando archivo 18/106: 814012.txt
# Procesando archivo 19/106: 130.txt
# Procesando archivo 20/106: 138.txt
# Procesando archivo 21/106: 137.txt
# Procesando archivo 22/106: 5514.txt
# Procesando archivo 23/106: 37139.txt
# Procesando archivo 24/106: 69.txt
# Procesando archivo 103/106: 4512.txt
# Procesando archivo 104/106: 2305.txt
# Procesando archivo 105/106: 9433.txt
# Procesando archivo 106/106: 55.txt

# %%
df_ner.head(26)
# Out:
#    patient_id  sentence_id                                           sentence  \
# 0         120            0  Mujer de 49 años diagnosticada en 2010 de canc...
# 1         120            0  Mujer de 49 años diagnosticada en 2010 de canc...
# 2         120            0  Mujer de 49 años diagnosticada en 2010 de canc...
# 3         120            0  Mujer de 49 años diagnosticada en 2010 de canc...
# 4         120            0  Mujer de 49 años diagnosticada en 2010 de canc...
# 5         120            0  Mujer de 49 años diagnosticada en 2010 de canc...
# 6         120            0  Mujer de 49 años diagnosticada en 2010 de canc...
# 7         120            1  Paciente operada el día 22/11/2010, con mastec...
# 8         120            1  Paciente operada el día 22/11/2010, con mastec...
# 9         120            1  Paciente operada el día 22/11/2010, con mastec...
# 10        120            2  AC x 4 entre 29/12/2010 y 09/03/2011 + Tamoxif...
# 11        120            2  AC x 4 entre 29/12/2010 y 09/03/2011 + Tamoxif...
# 12        120            2  AC x 4 entre 29/12/2010 y 09/03/2011 + Tamoxif...
# 13        120            2  AC x 4 entre 29/12/2010 y 09/03/2011 + Tamoxif...
# 14        120            2  AC x 4 entre 29/12/2010 y 09/03/2011 + Tamoxif...
# 15        120            2  AC x 4 entre 29/12/2010 y 09/03/2011 + Tamoxif...
# 16        120            2  AC x 4 entre 29/12/2010 y 09/03/2011 + Tamoxif...
# 17        120            2  AC x 4 entre 29/12/2010 y 09/03/2011 + Tamoxif...
# 18        120            3  No ha sido vista en Oncologia médica desde 201...
# 19        120            3  No ha sido vista en Oncologia médica desde 201...
# 20        120            3  No ha sido vista en Oncologia médica desde 201...
# 21        120            3  No ha sido vista en Oncologia médica desde 201...
# 22        120            4      Ultima mamografía que consta es del año 2014.
# 23        120           12                    No adenopatías axilares ni SCV.
# 24        120           13  Mujer de 45 años diagnosticada en 2013 de Carc...
# 25        120           13  Mujer de 45 años diagnosticada en 2013 de Carc...
#
#                         NER              label  start  end
# 0                   49 años                AGE      9   16
# 1             diagnosticada    OCURRENCE_EVENT     17   30
# 2                      2010               DATE     34   38
# 3    cancer de mama derecha     CANCER_CONCEPT     42   64
# 4                   T1cN0M0                TNM     66   73
# 5                 Ki67 30 %          BIOMARKER     75   84
# 6             Her2 negativo          BIOMARKER     87  100
# 7                   operada    OCURRENCE_EVENT      9   16
# 8                22/11/2010               DATE     24   34
# 9        mastectomía simple            SURGERY     40   58
# 10                       AC               DRUG      0    2
# 11                      x 4  LINE_CICLE_NUMBER      3    6
# 12               29/12/2010               DATE     13   23
# 13               09/03/2011               DATE     26   36
# 14               Tamoxifeno               DRUG     39   49
# 15                  04/2011               DATE     56   63
# 16               suspendido    OCURRENCE_EVENT     65   75
# 17             hace 5 meses      IMPLICIT_DATE     76   88
# 18         Oncologia médica   CLINICAL_SERVICE     20   36
# 19                     2016               DATE     43   47
# 20              ginecologia   CLINICAL_SERVICE     53   64
# 21                    2012.               DATE     71   76
# 22                    2014.               DATE     40   45
# 23  No adenopatías axilares        COMORBIDITY      0   23
# 24                  45 años                AGE      9   16
# 25            diagnosticada    OCURRENCE_EVENT     17   30

# %%
df_ner.to_csv("/content/drive/MyDrive/Tareas_Analitica_Datos_Salud/Tarea_2/entidades_extraidas_4_anvorja_model_entregable_1.csv")

# %% [markdown]
# # Entregable 2: Clasificar la negación o la incertidumbre de las oraciones de las historias

# %%
labels = ['B-NEG', 'B-NSCO', 'B-UNC', 'B-USCO', 'I-NEG', 'I-NSCO', 'I-UNC', 'I-USCO', 'O']

id2label = {k: v for k, v in enumerate(labels)}
label2id = {v: k for k, v in enumerate(labels)}

# %%
neg_model = "JuanSolarte99/bert-base-uncased-finetuned-ner-negation_detection_NUBES"
model = AutoModelForTokenClassification.from_pretrained(
    neg_model,
    id2label=id2label,
    label2id=label2id
)
tokenizer = AutoTokenizer.from_pretrained(neg_model)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %%
neg_pipeline = pipeline("ner", model=model, tokenizer=tokenizer, aggregation_strategy="simple")
# Out:
# Device set to use cuda:0

# %%
import os
import pandas as pd
from nltk.tokenize import sent_tokenize   # or the splitter you already use


def procesar_historias_clinicas_negacion(path):
    """
    Re-implemented so that consecutive entities of the same type (except FECHA)
    are fused into a single row in the output DataFrame.
    """
    datos = []
    archivos = [f for f in os.listdir(path) if f.endswith(".txt")]
    total_archivos = len(archivos)
    print(f"\nSe encontraron {total_archivos} archivos de historias clínicas.\n")

    for idx, archivo in enumerate(archivos, 1):
        print(f"Procesando archivo {idx}/{total_archivos}: {archivo}")
        ruta_archivo = os.path.join(path, archivo)

        with open(ruta_archivo, encoding='utf-8') as f:
            texto = f.read()

        for i, oracion in enumerate(sent_tokenize(texto)):
            entidades = neg_pipeline(oracion)

            for ent in entidades:
                datos.append({
                    "patient_id": archivo.replace(".txt", ""),
                    "sentence_id": i,
                    "sentence": oracion,
                    "NER": ent["word"],
                    "label": ent["entity_group"],
                    "start": ent["start"],
                    "end": ent["end"]
                })

    return pd.DataFrame(datos)

df_ner_negacion = procesar_historias_clinicas_negacion("/content/drive/MyDrive/Tareas_Analitica_Datos_Salud/Tarea_2/Notas_Cancer_Mama/")
# Out:
# Se encontraron 106 archivos de historias clínicas.
#
# Procesando archivo 1/106: 120.txt
# Procesando archivo 2/106: 553284.txt
# Procesando archivo 3/106: 5692361.txt
# Procesando archivo 4/106: 158.txt
# Procesando archivo 5/106: 139.txt
# Procesando archivo 6/106: 261062.txt
# Procesando archivo 7/106: 2567.txt
# Procesando archivo 8/106: 236.txt
# Procesando archivo 9/106: 330177_1.txt
# Procesando archivo 10/106: 2071255.txt
# Procesando archivo 11/106: 163.txt
# Procesando archivo 12/106: 153.txt
# Procesando archivo 13/106: 1010408.txt
# Procesando archivo 14/106: 131.txt
# Procesando archivo 15/106: 125.txt
# Procesando archivo 16/106: 2102.txt
# Procesando archivo 17/106: 1710.txt
# Procesando archivo 18/106: 814012.txt
# Procesando archivo 19/106: 130.txt
# Procesando archivo 20/106: 138.txt
# Procesando archivo 99/106: 141.txt
# Procesando archivo 100/106: 235.txt
# Procesando archivo 101/106: 7754.txt
# Procesando archivo 102/106: 154.txt
# Procesando archivo 103/106: 4512.txt
# Procesando archivo 104/106: 2305.txt
# Procesando archivo 105/106: 9433.txt
# Procesando archivo 106/106: 55.txt

# %%
df_ner_negacion.head(10)
# Out:
#   patient_id  sentence_id                                           sentence  \
# 0        120            0  Mujer de 49 años diagnosticada en 2010 de canc...
# 1        120            0  Mujer de 49 años diagnosticada en 2010 de canc...
# 2        120            0  Mujer de 49 años diagnosticada en 2010 de canc...
# 3        120            0  Mujer de 49 años diagnosticada en 2010 de canc...
# 4        120            0  Mujer de 49 años diagnosticada en 2010 de canc...
# 5        120            2  AC x 4 entre 29/12/2010 y 09/03/2011 + Tamoxif...
# 6        120            2  AC x 4 entre 29/12/2010 y 09/03/2011 + Tamoxif...
# 7        120            2  AC x 4 entre 29/12/2010 y 09/03/2011 + Tamoxif...
# 8        120            3  No ha sido vista en Oncologia médica desde 201...
# 9        120            3  No ha sido vista en Oncologia médica desde 201...
#
#                                             NER label  start  end
# 0                                           her  NSCO     87   90
# 1                                           ##2  NSCO     90   91
# 2                                            ne   NEG     92   94
# 3                                         ##gat   NEG     94   97
# 4                                         ##ivo  NSCO     97  100
# 5                                       suspend   NEG     65   72
# 6                                         ##ido  NSCO     72   75
# 7                                  hace 5 meses  NSCO     76   88
# 8                                            no   NEG      0    2
# 9  ha sido vista en oncologia medica desde 2016  NSCO      3   47

# %%
import pandas as pd
import json

def build_sentence_level_df(df_tokens: pd.DataFrame) -> pd.DataFrame:
    """
    Parameters
    ----------
    df_tokens : DataFrame
        Columns required:
        ─ patient_id, sentence_id, sentence, start, end, label

    Returns
    -------
    DataFrame
        One row per (patient_id, sentence_id, sentence) with:
        • spans : str   (JSON list of merged spans)
        • sentence_classified : str  (sentence with [TAG] in-line)
    """

    rows = []
    group_cols = ['patient_id', 'sentence_id', 'sentence']

    for (pid, sid, sent), g in df_tokens.groupby(group_cols, sort=False):
        # ---- 1. take spans for *this* sentence ---------------------------
        spans = (g[['start', 'end', 'label']]
                 .sort_values('start')
                 .query("label != 'O'")          # keep, if you use 'O'
                 .to_dict('records'))

        # ---- 2. merge adjacent sub-tokens with same label ----------------
        merged = []
        for sp in spans:
            if merged and sp['label'] == merged[-1]['label'] and sp['start'] == merged[-1]['end']:
                merged[-1]['end'] = sp['end']    # extend previous span
            else:
                merged.append(sp.copy())

        # ---- 3. build annotated sentence --------------------------------
        pieces, cursor = [], 0
        for sp in merged:
            if sp['start'] < cursor:             # overlap → skip
                continue
            pieces.append(sent[cursor:sp['start']])
            pieces.append((f"({sent[sp['start']:sp['end']]})"))
            pieces.append(f"[{sp['label']}]")
            cursor = sp['end']
        pieces.append(sent[cursor:])
        sentence_classified = ''.join(pieces)

        # ---- 4. collect row ---------------------------------------------
        rows.append({
            'patient_id': pid,
            'sentence_id': sid,
            'sentence': sent,
            'spans': json.dumps(merged, ensure_ascii=False),
            'sentence_classified': sentence_classified
        })

    return pd.DataFrame(rows)

# ------------------------------------------------------------------------
# USO:
df_sentences = build_sentence_level_df(df_ner_negacion)

# %%
# show entire column contents (no truncation)
pd.set_option('display.max_colwidth', None)
df_sentences[['sentence_classified']].head(10)
# Out:
#                                                                                                             sentence_classified
# 0  Mujer de 49 años diagnosticada en 2010 de cancer de mama derecha, T1cN0M0, Ki67 30 % , (Her2)[NSCO] (negat)[NEG](ivo)[NSCO].
# 1              AC x 4 entre 29/12/2010 y 09/03/2011 + Tamoxifeno desde 04/2011, (suspend)[NEG](ido)[NSCO] (hace 5 meses)[NSCO].
# 2                           (No)[NEG] (ha sido vista en Oncologia médica desde 2016)[NSCO] y (en ginecologia desde)[NSCO] 2012.
# 3                                                                                                   (No)[NEG] (sangrado)[NSCO].
# 4                                                                                              (No)[NEG] (líquido libre)[NSCO].
# 5                                                                                              (No)[NEG] (palpo nodulos)[NSCO].
# 6                                                                                (No)[NEG] (adenopatías axilares ni SCV)[NSCO].
# 7                                                                                (HER)[NSCO] (2)[NSCO] (ne)[NEG](gativo)[NSCO].
# 8                               -Náuseas secundarias a lo previo, resueltasEvolución: Buen estado general, (as)[NEG]intomática.
# 9  JUICIO DIAGNÓSTICO: (Car)[USCO](cino)[NSCO](ma)[USCO] (infi)[NSCO]lt(rante)[NSCO] triple (ne)[NEG](gativo)[NSCO] cT2 cN1 M0.

# %%
df_sentences.to_csv("/content/drive/MyDrive/Tareas_Analitica_Datos_Salud/Tarea_2/negaciones_extraidas_entregable_2.csv")

# %% [markdown]
# # Entregable 3: Integrar los modelos anteriores (NER, Negación) en un sript que permita procesar las historias clínicas y producir una base de datos estructurada.

# %%
df = pd.read_csv("/content/drive/MyDrive/Tareas_Analitica_Datos_Salud/Tarea_2/entidades_extraidas_4_anvorja_model_entregable_1.csv")

# Agregar columna de estado
df["Estado"] = None  # Por defecto

# Agrupar por patient_id para mostrar el progreso
pacientes = df["patient_id"].unique()
print(f"\n📄 Se encontraron {len(pacientes)} pacientes para análisis de negación.\n")

# Procesar por paciente y oración
for i, pid in enumerate(pacientes, 1):
    df_paciente = df[df["patient_id"] == pid]
    oraciones_unicas = df_paciente["sentence"].unique()

    print(f"👤 Procesando paciente {i}/{len(pacientes)}: {pid} ({len(oraciones_unicas)} oraciones)")

    for j, oracion in enumerate(oraciones_unicas, 1):
        # Mostrar progreso de oración
        print(f"   ↪ Oración {j}/{len(oraciones_unicas)}")

        #predicciones = neg_pipeline(oracion)

        # Obtener entidades en esa oración
        entidades = df[(df["patient_id"] == pid) & (df["sentence"] == oracion)]

        # Buscar si alguna entidad cae dentro del texto anotado
        for idx, fila in entidades.iterrows():
            # Pasar al modelo
            predicciones = neg_pipeline(str(fila["NER"]))

            if len(predicciones) > 1:
                tipos = [pred["entity_group"] for pred in predicciones]
                if ("NEG" in tipos) or ("NSCO" in tipos):
                    df.at[idx, "Estado"] = "NEGATIVE"
                elif ("UNC" in tipos) or ("USCO" in tipos):
                    df.at[idx, "Estado"] = "UNCERTAIN"
                continue

            if len(predicciones) == 0:
                df.at[idx, "Estado"] = "POSITIVE"
                continue

            pred = predicciones[0]

            if pred["entity_group"] in ("NEG", "NSCO"):
                df.at[idx, "Estado"] = "NEGATIVE"
            elif pred["entity_group"] in ("UNC", "USCO"):
                df.at[idx, "Estado"] = "UNCERTAIN"
            else:
                df.at[idx, "Estado"] = "POSITIVE"
# Out:
# 📄 Se encontraron 106 pacientes para análisis de negación.
#
# 👤 Procesando paciente 1/106: 120 (12 oraciones)
#    ↪ Oración 1/12
#    ↪ Oración 2/12
#    ↪ Oración 3/12
#    ↪ Oración 4/12
#    ↪ Oración 5/12
#    ↪ Oración 6/12
#    ↪ Oración 7/12
#    ↪ Oración 8/12
#    ↪ Oración 9/12
#    ↪ Oración 10/12
#    ↪ Oración 11/12
#    ↪ Oración 12/12
# 👤 Procesando paciente 2/106: 553284 (5 oraciones)
#    ↪ Oración 1/5
#    ↪ Oración 2/5
#    ↪ Oración 3/5
#    ↪ Oración 4/5
#    ↪ Oración 5/5
# 👤 Procesando paciente 3/106: 5692361 (6 oraciones)
#    ↪ Oración 1/6
#    ↪ Oración 2/6
#    ↪ Oración 3/6
#    ↪ Oración 4/6
#    ↪ Oración 5/6
#    ↪ Oración 6/6
# 👤 Procesando paciente 4/106: 158 (8 oraciones)
#    ↪ Oración 1/8
#    ↪ Oración 2/8
#    ↪ Oración 3/8
#    ↪ Oración 4/8
#    ↪ Oración 5/8
#    ↪ Oración 6/8
#    ↪ Oración 7/8
#    ↪ Oración 8/8
# 👤 Procesando paciente 5/106: 139 (10 oraciones)
#    ↪ Oración 1/10
#    ↪ Oración 2/10
#    ↪ Oración 3/10
#    ↪ Oración 4/10
#    ↪ Oración 5/10
#    ↪ Oración 6/10
#    ↪ Oración 7/10
#    ↪ Oración 8/10
#    ↪ Oración 9/10
#    ↪ Oración 10/10
# 👤 Procesando paciente 6/106: 261062 (14 oraciones)
#    ↪ Oración 1/14
#    ↪ Oración 2/14
#    ↪ Oración 3/14
#    ↪ Oración 4/14
#    ↪ Oración 5/14
#    ↪ Oración 6/14
#    ↪ Oración 7/14
#    ↪ Oración 8/14
#    ↪ Oración 9/14
#    ↪ Oración 10/14
#    ↪ Oración 11/14
#    ↪ Oración 12/14
#    ↪ Oración 13/14
#    ↪ Oración 14/14
# 👤 Procesando paciente 7/106: 2567 (10 oraciones)
#    ↪ Oración 1/10
#    ↪ Oración 2/10
#    ↪ Oración 3/10
#    ↪ Oración 4/10
#    ↪ Oración 5/10
#    ↪ Oración 6/10
#    ↪ Oración 7/10
#    ↪ Oración 8/10
#    ↪ Oración 9/10
#    ↪ Oración 10/10
# 👤 Procesando paciente 8/106: 236 (15 oraciones)
#    ↪ Oración 1/15
#    ↪ Oración 2/15
#    ↪ Oración 3/15
#    ↪ Oración 4/15
#    ↪ Oración 5/15
#    ↪ Oración 6/15
#    ↪ Oración 7/15
#    ↪ Oración 8/15
#    ↪ Oración 9/15
#    ↪ Oración 10/15
#    ↪ Oración 11/15
#    ↪ Oración 12/15
#    ↪ Oración 13/15
#    ↪ Oración 10/11
#    ↪ Oración 11/11
# 👤 Procesando paciente 38/106: 242186_1 (4 oraciones)
#    ↪ Oración 1/4
#    ↪ Oración 2/4
#    ↪ Oración 3/4
#    ↪ Oración 4/4
# 👤 Procesando paciente 39/106: 162 (10 oraciones)
#    ↪ Oración 1/10
#    ↪ Oración 2/10
#    ↪ Oración 3/10
#    ↪ Oración 4/10
#    ↪ Oración 5/10
#    ↪ Oración 6/10
#    ↪ Oración 7/10
#    ↪ Oración 8/10
#    ↪ Oración 9/10
#    ↪ Oración 10/10
# 👤 Procesando paciente 40/106: 2759 (7 oraciones)
#    ↪ Oración 1/7
#    ↪ Oración 2/7
#    ↪ Oración 3/7
#    ↪ Oración 4/7
#    ↪ Oración 5/7
#    ↪ Oración 6/7
#    ↪ Oración 7/7
# 👤 Procesando paciente 41/106: 127 (12 oraciones)
#    ↪ Oración 1/12
#    ↪ Oración 2/12
#    ↪ Oración 3/12
#    ↪ Oración 4/12
#    ↪ Oración 5/12
#    ↪ Oración 6/12
#    ↪ Oración 7/12
#    ↪ Oración 8/12
#    ↪ Oración 9/12
#    ↪ Oración 10/12
#    ↪ Oración 11/12
#    ↪ Oración 12/12
# 👤 Procesando paciente 42/106: 101 (5 oraciones)
#    ↪ Oración 1/5
#    ↪ Oración 2/5
#    ↪ Oración 3/5
#    ↪ Oración 4/5
#    ↪ Oración 5/5
# 👤 Procesando paciente 43/106: 146 (2 oraciones)
#    ↪ Oración 1/2
#    ↪ Oración 2/2
# 👤 Procesando paciente 44/106: 151 (15 oraciones)
#    ↪ Oración 1/15
#    ↪ Oración 2/15
#    ↪ Oración 3/15
#    ↪ Oración 4/15
#    ↪ Oración 5/15
#    ↪ Oración 6/15
#    ↪ Oración 7/15
#    ↪ Oración 8/15
#    ↪ Oración 9/15
#    ↪ Oración 10/15
#    ↪ Oración 11/15
#    ↪ Oración 12/15
#    ↪ Oración 13/15
#    ↪ Oración 14/15
#    ↪ Oración 15/15
# 👤 Procesando paciente 45/106: 8140123m (11 oraciones)
#    ↪ Oración 1/11
#    ↪ Oración 2/11
#    ↪ Oración 3/11
#    ↪ Oración 4/11
#    ↪ Oración 5/11
#    ↪ Oración 6/11
#    ↪ Oración 7/11
#    ↪ Oración 8/11
#    ↪ Oración 9/11
#    ↪ Oración 10/11
#    ↪ Oración 11/11
# 👤 Procesando paciente 46/106: 240 (9 oraciones)
#    ↪ Oración 1/9
#    ↪ Oración 2/9
#    ↪ Oración 3/9
#    ↪ Oración 4/9
#    ↪ Oración 5/9
#    ↪ Oración 6/9
#    ↪ Oración 7/9
#    ↪ Oración 8/9
#    ↪ Oración 9/9
# 👤 Procesando paciente 47/106: 156 (7 oraciones)
#    ↪ Oración 1/7
#    ↪ Oración 2/7
#    ↪ Oración 3/7
#    ↪ Oración 4/7
#    ↪ Oración 5/7
#    ↪ Oración 6/7
#    ↪ Oración 7/7
# 👤 Procesando paciente 48/106: 100 (5 oraciones)
#    ↪ Oración 1/5
#    ↪ Oración 2/5
#    ↪ Oración 3/5
#    ↪ Oración 4/5
#    ↪ Oración 5/5
# 👤 Procesando paciente 49/106: 155 (12 oraciones)
#    ↪ Oración 1/12
#    ↪ Oración 2/12
#    ↪ Oración 3/12
#    ↪ Oración 4/12
#    ↪ Oración 5/12
#    ↪ Oración 6/12
#    ↪ Oración 7/12
#    ↪ Oración 8/12
#    ↪ Oración 9/12
#    ↪ Oración 10/12
#    ↪ Oración 11/12
#    ↪ Oración 12/12
# 👤 Procesando paciente 50/106: 237 (30 oraciones)
#    ↪ Oración 1/30
#    ↪ Oración 2/30
#    ↪ Oración 3/30
#    ↪ Oración 4/30
#    ↪ Oración 5/30
#    ↪ Oración 6/30
#    ↪ Oración 7/30
#    ↪ Oración 8/30
#    ↪ Oración 9/30
#    ↪ Oración 10/30
#    ↪ Oración 11/30
#    ↪ Oración 12/30
#    ↪ Oración 13/30
#    ↪ Oración 14/30
#    ↪ Oración 15/30
#    ↪ Oración 16/30
#    ↪ Oración 17/30
#    ↪ Oración 18/30
#    ↪ Oración 19/30
#    ↪ Oración 20/30
#    ↪ Oración 21/30
#    ↪ Oración 22/30
#    ↪ Oración 23/30
#    ↪ Oración 24/30
#    ↪ Oración 25/30
#    ↪ Oración 26/30
#    ↪ Oración 27/30
#    ↪ Oración 28/30
#    ↪ Oración 29/30
#    ↪ Oración 30/30
# 👤 Procesando paciente 51/106: 142 (3 oraciones)
#    ↪ Oración 1/3
#    ↪ Oración 2/3
#    ↪ Oración 3/3
# 👤 Procesando paciente 52/106: 129 (13 oraciones)
#    ↪ Oración 1/13
#    ↪ Oración 2/13
#    ↪ Oración 3/13
#    ↪ Oración 4/13
#    ↪ Oración 5/13
#    ↪ Oración 6/13
#    ↪ Oración 7/13
#    ↪ Oración 8/13
#    ↪ Oración 9/13
#    ↪ Oración 10/13
#    ↪ Oración 11/13
#    ↪ Oración 12/13
#    ↪ Oración 13/13
# 👤 Procesando paciente 53/106: 45812 (7 oraciones)
#    ↪ Oración 1/7
#    ↪ Oración 2/7
#    ↪ Oración 3/7
#    ↪ Oración 4/7
#    ↪ Oración 5/7
#    ↪ Oración 6/7
#    ↪ Oración 7/7
# 👤 Procesando paciente 54/106: 136 (7 oraciones)
#    ↪ Oración 1/7
#    ↪ Oración 2/7
#    ↪ Oración 3/7
#    ↪ Oración 4/7
#    ↪ Oración 5/7
#    ↪ Oración 6/7
#    ↪ Oración 7/7
# 👤 Procesando paciente 55/106: 1567 (11 oraciones)
#    ↪ Oración 1/11
#    ↪ Oración 2/11
#    ↪ Oración 3/11
#    ↪ Oración 4/11
#    ↪ Oración 5/11
#    ↪ Oración 6/11
#    ↪ Oración 7/11
#    ↪ Oración 8/11
#    ↪ Oración 9/11
#    ↪ Oración 10/11
#    ↪ Oración 11/11
# 👤 Procesando paciente 56/106: 241 (13 oraciones)
#    ↪ Oración 1/13
#    ↪ Oración 2/13
#    ↪ Oración 3/13
#    ↪ Oración 4/13
#    ↪ Oración 5/13
#    ↪ Oración 6/13
#    ↪ Oración 7/13
#    ↪ Oración 8/13
#    ↪ Oración 11/13
#    ↪ Oración 12/13
#    ↪ Oración 13/13
# 👤 Procesando paciente 75/106: 122 (12 oraciones)
#    ↪ Oración 1/12
#    ↪ Oración 2/12
#    ↪ Oración 3/12
#    ↪ Oración 4/12
#    ↪ Oración 5/12
#    ↪ Oración 6/12
#    ↪ Oración 7/12
#    ↪ Oración 8/12
#    ↪ Oración 9/12
#    ↪ Oración 10/12
#    ↪ Oración 11/12
#    ↪ Oración 12/12
# 👤 Procesando paciente 76/106: 234 (13 oraciones)
#    ↪ Oración 1/13
#    ↪ Oración 2/13
#    ↪ Oración 3/13
#    ↪ Oración 4/13
#    ↪ Oración 5/13
#    ↪ Oración 6/13
#    ↪ Oración 7/13
#    ↪ Oración 8/13
#    ↪ Oración 9/13
#    ↪ Oración 10/13
#    ↪ Oración 11/13
#    ↪ Oración 12/13
#    ↪ Oración 13/13
# 👤 Procesando paciente 77/106: 3389 (8 oraciones)
#    ↪ Oración 1/8
#    ↪ Oración 2/8
#    ↪ Oración 3/8
#    ↪ Oración 4/8
#    ↪ Oración 5/8
#    ↪ Oración 6/8
#    ↪ Oración 7/8
#    ↪ Oración 8/8
# 👤 Procesando paciente 78/106: 912866 (6 oraciones)
#    ↪ Oración 1/6
#    ↪ Oración 2/6
#    ↪ Oración 3/6
#    ↪ Oración 4/6
#    ↪ Oración 5/6
#    ↪ Oración 6/6
# 👤 Procesando paciente 79/106: 144 (2 oraciones)
#    ↪ Oración 1/2
#    ↪ Oración 2/2
# 👤 Procesando paciente 80/106: 2060668 (3 oraciones)
#    ↪ Oración 1/3
#    ↪ Oración 2/3
#    ↪ Oración 3/3
# 👤 Procesando paciente 81/106: 143 (5 oraciones)
#    ↪ Oración 1/5
#    ↪ Oración 2/5
#    ↪ Oración 3/5
#    ↪ Oración 4/5
#    ↪ Oración 5/5
# 👤 Procesando paciente 82/106: 145 (6 oraciones)
#    ↪ Oración 1/6
#    ↪ Oración 2/6
#    ↪ Oración 3/6
#    ↪ Oración 4/6
#    ↪ Oración 5/6
#    ↪ Oración 6/6
# 👤 Procesando paciente 83/106: 100(1) (10 oraciones)
#    ↪ Oración 1/10
#    ↪ Oración 2/10
#    ↪ Oración 3/10
#    ↪ Oración 4/10
#    ↪ Oración 5/10
#    ↪ Oración 6/10
#    ↪ Oración 7/10
#    ↪ Oración 8/10
#    ↪ Oración 9/10
#    ↪ Oración 10/10
# 👤 Procesando paciente 84/106: 130m (26 oraciones)
#    ↪ Oración 1/26
#    ↪ Oración 2/26
#    ↪ Oración 3/26
#    ↪ Oración 4/26
#    ↪ Oración 5/26
#    ↪ Oración 6/26
#    ↪ Oración 7/26
#    ↪ Oración 8/26
#    ↪ Oración 9/26
#    ↪ Oración 10/26
#    ↪ Oración 11/26
#    ↪ Oración 12/26
#    ↪ Oración 13/26
#    ↪ Oración 14/26
#    ↪ Oración 15/26
#    ↪ Oración 16/26
#    ↪ Oración 17/26
#    ↪ Oración 18/26
#    ↪ Oración 19/26
#    ↪ Oración 20/26
#    ↪ Oración 21/26
#    ↪ Oración 22/26
#    ↪ Oración 23/26
#    ↪ Oración 24/26
#    ↪ Oración 25/26
#    ↪ Oración 26/26
# 👤 Procesando paciente 85/106: 161 (8 oraciones)
#    ↪ Oración 1/8
#    ↪ Oración 2/8
#    ↪ Oración 3/8
#    ↪ Oración 4/8
#    ↪ Oración 5/8
#    ↪ Oración 6/8
#    ↪ Oración 7/8
#    ↪ Oración 8/8
# 👤 Procesando paciente 86/106: 134 (13 oraciones)
#    ↪ Oración 1/13
#    ↪ Oración 2/13
#    ↪ Oración 3/13
#    ↪ Oración 4/13
#    ↪ Oración 5/13
#    ↪ Oración 6/13
#    ↪ Oración 7/13
#    ↪ Oración 8/13
#    ↪ Oración 9/13
#    ↪ Oración 10/13
#    ↪ Oración 11/13
#    ↪ Oración 12/13
#    ↪ Oración 13/13
# 👤 Procesando paciente 87/106: 5547 (6 oraciones)
#    ↪ Oración 1/6
#    ↪ Oración 2/6
#    ↪ Oración 3/6
#    ↪ Oración 4/6
#    ↪ Oración 5/6
#    ↪ Oración 6/6
# 👤 Procesando paciente 88/106: 1081698 (10 oraciones)
#    ↪ Oración 1/10
#    ↪ Oración 2/10
#    ↪ Oración 3/10
#    ↪ Oración 4/10
#    ↪ Oración 5/10
#    ↪ Oración 6/10
#    ↪ Oración 7/10
#    ↪ Oración 8/10
#    ↪ Oración 9/10
#    ↪ Oración 10/10
# 👤 Procesando paciente 89/106: 36687 (12 oraciones)
#    ↪ Oración 1/12
#    ↪ Oración 2/12
#    ↪ Oración 3/12
#    ↪ Oración 4/12
#    ↪ Oración 5/12
#    ↪ Oración 6/12
#    ↪ Oración 7/12
#    ↪ Oración 8/12
#    ↪ Oración 9/12
#    ↪ Oración 10/12
#    ↪ Oración 11/12
#    ↪ Oración 12/12
# 👤 Procesando paciente 90/106: 1126737 (7 oraciones)
#    ↪ Oración 1/7
#    ↪ Oración 2/7
#    ↪ Oración 3/7
#    ↪ Oración 4/7
#    ↪ Oración 5/7
#    ↪ Oración 6/7
#    ↪ Oración 7/7
# 👤 Procesando paciente 91/106: 152 (12 oraciones)
#    ↪ Oración 1/12
#    ↪ Oración 2/12
#    ↪ Oración 3/12
#    ↪ Oración 4/12
#    ↪ Oración 5/12
#    ↪ Oración 6/12
#    ↪ Oración 7/12
#    ↪ Oración 8/12
#    ↪ Oración 9/12
#    ↪ Oración 10/12
#    ↪ Oración 11/12
#    ↪ Oración 12/12
# 👤 Procesando paciente 92/106: 124 (7 oraciones)
#    ↪ Oración 1/7
#    ↪ Oración 2/7
#    ↪ Oración 3/7
#    ↪ Oración 4/7
#    ↪ Oración 5/7
#    ↪ Oración 6/7
#    ↪ Oración 7/7
# 👤 Procesando paciente 93/106: 499061 (8 oraciones)
#    ↪ Oración 1/8
#    ↪ Oración 2/8
#    ↪ Oración 3/8
#    ↪ Oración 4/8
#    ↪ Oración 5/8
#    ↪ Oración 6/8
#    ↪ Oración 7/8
#    ↪ Oración 8/8
# 👤 Procesando paciente 94/106: 2501 (5 oraciones)
# 👤 Procesando paciente 103/106: 4512 (9 oraciones)
#    ↪ Oración 1/9
#    ↪ Oración 2/9
#    ↪ Oración 3/9
#    ↪ Oración 4/9
#    ↪ Oración 5/9
#    ↪ Oración 6/9
#    ↪ Oración 7/9
#    ↪ Oración 8/9
#    ↪ Oración 9/9
# 👤 Procesando paciente 104/106: 2305 (10 oraciones)
#    ↪ Oración 1/10
#    ↪ Oración 2/10
#    ↪ Oración 3/10
#    ↪ Oración 4/10
#    ↪ Oración 5/10
#    ↪ Oración 6/10
#    ↪ Oración 7/10
#    ↪ Oración 8/10
#    ↪ Oración 9/10
#    ↪ Oración 10/10
# 👤 Procesando paciente 105/106: 9433 (9 oraciones)
#    ↪ Oración 1/9
#    ↪ Oración 2/9
#    ↪ Oración 3/9
#    ↪ Oración 4/9
#    ↪ Oración 5/9
#    ↪ Oración 6/9
#    ↪ Oración 7/9
#    ↪ Oración 8/9
#    ↪ Oración 9/9
# 👤 Procesando paciente 106/106: 55 (3 oraciones)
#    ↪ Oración 1/3
#    ↪ Oración 2/3
#    ↪ Oración 3/3

# %%
df.head(26)
# Out:
#     Unnamed: 0 patient_id  sentence_id  \
# 0            0        120            0
# 1            1        120            0
# 2            2        120            0
# 3            3        120            0
# 4            4        120            0
# 5            5        120            0
# 6            6        120            0
# 7            7        120            1
# 8            8        120            1
# 9            9        120            1
# 10          10        120            2
# 11          11        120            2
# 12          12        120            2
# 13          13        120            2
# 14          14        120            2
# 15          15        120            2
# 16          16        120            2
# 17          17        120            2
# 18          18        120            3
# 19          19        120            3
# 20          20        120            3
# 21          21        120            3
# 22          22        120            4
# 23          23        120           12
# 24          24        120           13
# 25          25        120           13
#
#                                                                                                                   sentence  \
# 0                    Mujer de 49 años diagnosticada en 2010 de cancer de mama derecha, T1cN0M0, Ki67 30 % , Her2 negativo.
# 1                    Mujer de 49 años diagnosticada en 2010 de cancer de mama derecha, T1cN0M0, Ki67 30 % , Her2 negativo.
# 2                    Mujer de 49 años diagnosticada en 2010 de cancer de mama derecha, T1cN0M0, Ki67 30 % , Her2 negativo.
# 3                    Mujer de 49 años diagnosticada en 2010 de cancer de mama derecha, T1cN0M0, Ki67 30 % , Her2 negativo.
# 4                    Mujer de 49 años diagnosticada en 2010 de cancer de mama derecha, T1cN0M0, Ki67 30 % , Her2 negativo.
# 5                    Mujer de 49 años diagnosticada en 2010 de cancer de mama derecha, T1cN0M0, Ki67 30 % , Her2 negativo.
# 6                    Mujer de 49 años diagnosticada en 2010 de cancer de mama derecha, T1cN0M0, Ki67 30 % , Her2 negativo.
# 7                                                              Paciente operada el día 22/11/2010, con mastectomía simple.
# 8                                                              Paciente operada el día 22/11/2010, con mastectomía simple.
# 9                                                              Paciente operada el día 22/11/2010, con mastectomía simple.
# 10                               AC x 4 entre 29/12/2010 y 09/03/2011 + Tamoxifeno desde 04/2011, suspendido hace 5 meses.
# 11                               AC x 4 entre 29/12/2010 y 09/03/2011 + Tamoxifeno desde 04/2011, suspendido hace 5 meses.
# 12                               AC x 4 entre 29/12/2010 y 09/03/2011 + Tamoxifeno desde 04/2011, suspendido hace 5 meses.
# 13                               AC x 4 entre 29/12/2010 y 09/03/2011 + Tamoxifeno desde 04/2011, suspendido hace 5 meses.
# 14                               AC x 4 entre 29/12/2010 y 09/03/2011 + Tamoxifeno desde 04/2011, suspendido hace 5 meses.
# 15                               AC x 4 entre 29/12/2010 y 09/03/2011 + Tamoxifeno desde 04/2011, suspendido hace 5 meses.
# 16                               AC x 4 entre 29/12/2010 y 09/03/2011 + Tamoxifeno desde 04/2011, suspendido hace 5 meses.
# 17                               AC x 4 entre 29/12/2010 y 09/03/2011 + Tamoxifeno desde 04/2011, suspendido hace 5 meses.
# 18                                            No ha sido vista en Oncologia médica desde 2016 y en ginecologia desde 2012.
# 19                                            No ha sido vista en Oncologia médica desde 2016 y en ginecologia desde 2012.
# 20                                            No ha sido vista en Oncologia médica desde 2016 y en ginecologia desde 2012.
# 21                                            No ha sido vista en Oncologia médica desde 2016 y en ginecologia desde 2012.
# 22                                                                           Ultima mamografía que consta es del año 2014.
# 23                                                                                         No adenopatías axilares ni SCV.
# 24  Mujer de 45 años diagnosticada en 2013 de Carcinoma ductal infiltrante de mama izquierda, pT1c(m) pN0(sn); estadio II.
# 25  Mujer de 45 años diagnosticada en 2013 de Carcinoma ductal infiltrante de mama izquierda, pT1c(m) pN0(sn); estadio II.
#
#                         NER              label  start  end    Estado
# 0                   49 años                AGE      9   16  POSITIVE
# 1             diagnosticada    OCURRENCE_EVENT     17   30  POSITIVE
# 2                      2010               DATE     34   38  POSITIVE
# 3    cancer de mama derecha     CANCER_CONCEPT     42   64  POSITIVE
# 4                   T1cN0M0                TNM     66   73  POSITIVE
# 5                 Ki67 30 %          BIOMARKER     75   84  POSITIVE
# 6             Her2 negativo          BIOMARKER     87  100  NEGATIVE
# 7                   operada    OCURRENCE_EVENT      9   16  POSITIVE
# 8                22/11/2010               DATE     24   34  POSITIVE
# 9        mastectomía simple            SURGERY     40   58  POSITIVE
# 10                       AC               DRUG      0    2  POSITIVE
# 11                      x 4  LINE_CICLE_NUMBER      3    6  POSITIVE
# 12               29/12/2010               DATE     13   23  POSITIVE
# 13               09/03/2011               DATE     26   36  POSITIVE
# 14               Tamoxifeno               DRUG     39   49  POSITIVE
# 15                  04/2011               DATE     56   63  POSITIVE
# 16               suspendido    OCURRENCE_EVENT     65   75  NEGATIVE
# 17             hace 5 meses      IMPLICIT_DATE     76   88  POSITIVE
# 18         Oncologia médica   CLINICAL_SERVICE     20   36  POSITIVE
# 19                     2016               DATE     43   47  POSITIVE
# 20              ginecologia   CLINICAL_SERVICE     53   64  POSITIVE
# 21                    2012.               DATE     71   76  POSITIVE
# 22                    2014.               DATE     40   45  POSITIVE
# 23  No adenopatías axilares        COMORBIDITY      0   23  NEGATIVE
# 24                  45 años                AGE      9   16  POSITIVE
# 25            diagnosticada    OCURRENCE_EVENT     17   30  POSITIVE

# %%
df.to_csv("/content/drive/MyDrive/Tareas_Analitica_Datos_Salud/Tarea_2/entidades_con_estado_entregable_3.csv")
